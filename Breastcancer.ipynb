# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\hemae\OneDrive\Desktop\cancer prediction\breast_cancer_web\data\breast-cancer-dataset.csv")

# %%
df.head()
# Out:
#    S/N  Year  Age  Menopause Tumor Size (cm) Inv-Nodes Breast Metastasis  \
# 0    1  2019   40          1               2         0  Right          0
# 1    2  2019   39          1               2         0   Left          0
# 2    3  2019   45          0               4         0   Left          0
# 3    4  2019   26          1               3         0   Left          0
# 4    5  2019   21          1               1         0  Right          0
#
#   Breast Quadrant History Diagnosis Result
# 0     Upper inner       0           Benign
# 1     Upper outer       0           Benign
# 2     Lower outer       0           Benign
# 3     Lower inner       1           Benign
# 4     Upper outer       1           Benign

# %%
df.tail()
# Out:
#      S/N  Year  Age  Menopause Tumor Size (cm) Inv-Nodes Breast Metastasis  \
# 208  209  2020   49          1               6         3  Right          1
# 209  210  2020   28          1               3         0   Left          0
# 210  211  2020   22          1               1         0   Left          0
# 211  212  2020   19          1               1         0   Left          0
# 212  213  2020   50          0               4         0  Right          0
#
#     Breast Quadrant History Diagnosis Result
# 208     Lower inner       1        Malignant
# 209     Upper inner       0           Benign
# 210     Upper outer       1           Benign
# 211     Lower inner       1           Benign
# 212     Lower outer       1           Benign

# %%
df.shape
# Out:
# (213, 11)

# %%
df.dtypes
# Out:
# S/N                  int64
# Year                object
# Age                  int64
# Menopause            int64
# Tumor Size (cm)     object
# Inv-Nodes           object
# Breast              object
# Metastasis          object
# Breast Quadrant     object
# History             object
# Diagnosis Result    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   S/N               213 non-null    int64
#  1   Year              213 non-null    object
#  2   Age               213 non-null    int64
#  3   Menopause         213 non-null    int64
#  4   Tumor Size (cm)   213 non-null    object
#  5   Inv-Nodes         213 non-null    object
#  6   Breast            213 non-null    object
#  7   Metastasis        213 non-null    object
#  8   Breast Quadrant   213 non-null    object
#  9   History           213 non-null    object
#  10  Diagnosis Result  213 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 18.4+ KB

# %%
df.isnull().sum()
# Out:
# S/N                 0
# Year                0
# Age                 0
# Menopause           0
# Tumor Size (cm)     0
# Inv-Nodes           0
# Breast              0
# Metastasis          0
# Breast Quadrant     0
# History             0
# Diagnosis Result    0
# dtype: int64

# %%
df.describe()
# Out:
#               S/N         Age   Menopause
# count  213.000000  213.000000  213.000000
# mean   107.000000   39.784038    0.666667
# std     61.631972   14.096712    0.472515
# min      1.000000   13.000000    0.000000
# 25%     54.000000   30.000000    0.000000
# 50%    107.000000   40.000000    1.000000
# 75%    160.000000   49.000000    1.000000
# max    213.000000   77.000000    1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Diagnosis Result', data=df)
plt.title('Result Showing Breast Cancer Diagnosis')
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Menopause',data=df)
plt.title('Result Showing Breast Cancer Diagnosis')
plt.xlabel('Menopause')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Age',data=df)
plt.title('Result Showing Breast Cancer Diagnosis')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='History',data=df)
plt.title('Result Showing Breast Cancer Diagnosis')
plt.xlabel('History')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='Tumor Size (cm)',data=df)
plt.title('Result Showing Breast Cancer Diagnosis')
plt.xlabel('Tumor Size (cm)')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='Breast Quadrant',data=df)
plt.title('Result Showing Breast Cancer Diagnosis')
plt.xlabel('Breast Quadrant')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.pointplot(x='Inv-Nodes',data=df)
plt.title('Result Showing Breast Cancer Diagnosis')
plt.xlabel('Inv-Nodes')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Breast',data=df)
plt.title('Result Showing Breast Cancer Diagnosis')
plt.xlabel('Breast')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Metastasis',data=df)
plt.title('Result Showing Breast Cancer Diagnosis')
plt.xlabel('Metastasis')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='Metastasis',y='Diagnosis Result',hue='Age',data=df)
plt.title('Results showing Breast Cancer Diagnosis')
plt.xlabel('Metastasis')
plt.ylabel('Diagnosis Result')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Diagnosis Result',y='Menopause',hue='Age',data=df)
plt.title('Results showing Breast Cancer Diagnosis')
plt.xlabel('Diagnosis Result')
plt.ylabel('Menopause')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(x='Inv-Nodes',y='Breast',data=df)
plt.title('Results showing Breast Cancer Diagnosis')
plt.xlabel('Inv-Nodes')
plt.ylabel('Breast')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Tumor Size (cm)',data=df)
plt.title('Result Showing Breast Cancer Diagnosis')
plt.xlabel('Tumor Size (cm)')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Correlation matrix for Breast Cancer Diagnosis dataset')
plt.show()

# %%
df.head()
# Out:
#    S/N  Year  Age  Menopause Tumor Size (cm) Inv-Nodes Breast Metastasis  \
# 0    1  2019   40          1               2         0  Right          0
# 1    2  2019   39          1               2         0   Left          0
# 2    3  2019   45          0               4         0   Left          0
# 3    4  2019   26          1               3         0   Left          0
# 4    5  2019   21          1               1         0  Right          0
#
#   Breast Quadrant History Diagnosis Result
# 0     Upper inner       0           Benign
# 1     Upper outer       0           Benign
# 2     Lower outer       0           Benign
# 3     Lower inner       1           Benign
# 4     Upper outer       1           Benign

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Year']=le.fit_transform(df['Year'])

# %%
df['Diagnosis Result']=le.fit_transform(df['Diagnosis Result'])

# %%
df['Breast']=le.fit_transform(df['Breast'])

# %%
df['Breast Quadrant']=le.fit_transform(df['Breast Quadrant'])

# %%
df['Tumor Size (cm)']=le.fit_transform(df['Tumor Size (cm)'])

# %%
df['Inv-Nodes']=le.fit_transform(df['Inv-Nodes'])

# %%
df['Metastasis']=le.fit_transform(df['Metastasis'])

# %%
df['History']=le.fit_transform(df['History'])

# %%
df.head()
# Out:
#    S/N  Year  Age  Menopause  Tumor Size (cm)  Inv-Nodes  Breast  Metastasis  \
# 0    1     1   40          1                5          1       2           1
# 1    2     1   39          1                5          1       1           1
# 2    3     1   45          0                7          1       1           1
# 3    4     1   26          1                6          1       1           1
# 4    5     1   21          1                1          1       2           1
#
#    Breast Quadrant  History  Diagnosis Result
# 0                3        1                 0
# 1                4        1                 0
# 2                2        1                 0
# 3                1        2                 0
# 4                4        2                 0

# %%
print(df['Diagnosis Result'].value_counts())
print(df['Diagnosis Result'].value_counts(normalize=True))

import matplotlib.pyplot as plt
df['Diagnosis Result'].value_counts().plot(kind='bar')
plt.title('Results showing Diagnosis')
plt.xlabel('Diagnosis Result')
plt.ylabel('count')
plt.show()
# Out:
# Diagnosis Result
# 0    120
# 1     93
# Name: count, dtype: int64
# Diagnosis Result
# 0    0.56338
# 1    0.43662
# Name: proportion, dtype: float64

# %%
from sklearn.utils import resample

df_majority=df[df['Diagnosis Result'] == 0]
df_minority=df[df['Diagnosis Result'] == 1]

df_minority_oversampled = resample(df_minority,
                                   replace=True, 
                                   n_samples=len(df_majority),
                                   random_state=42)

df_oversampled=pd.concat([df_majority, df_minority_oversampled])

df_oversampled['Diagnosis Result'].value_counts(normalize=True)
# Out:
# Diagnosis Result
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
df_oversampled.head()
# Out:
#    S/N  Year  Age  Menopause  Tumor Size (cm)  Inv-Nodes  Breast  Metastasis  \
# 0    1     1   40          1                5          1       2           1
# 1    2     1   39          1                5          1       1           1
# 2    3     1   45          0                7          1       1           1
# 3    4     1   26          1                6          1       1           1
# 4    5     1   21          1                1          1       2           1
#
#    Breast Quadrant  History  Diagnosis Result
# 0                3        1                 0
# 1                4        1                 0
# 2                2        1                 0
# 3                1        2                 0
# 4                4        2                 0

# %%
print(df_oversampled['Diagnosis Result'].value_counts())
print(df_oversampled['Diagnosis Result'].value_counts(normalize=True))

import matplotlib.pyplot as plt
df_oversampled['Diagnosis Result'].value_counts().plot(kind='bar')
plt.title('Results showing Diagnosis')
plt.xlabel('Diagnosis Result')
plt.ylabel('count')
plt.show()
# Out:
# Diagnosis Result
# 0    120
# 1    120
# Name: count, dtype: int64
# Diagnosis Result
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
numeric_cols=df.select_dtypes(include=np.number).columns
for col in numeric_cols:
    plt.figure(figsize=(6,6))
    sns.boxplot(y=df[col])
    plt.title(f'boxplot of {col}',fontsize=12)
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()

# %%
X=df_oversampled[['Year','Age','Menopause','Tumor Size (cm)','Inv-Nodes','Breast','Metastasis','Breast Quadrant','History']]
Y=df_oversampled['Diagnosis Result']

# %%
from scipy.stats import skew,kurtosis

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler() 
x=scaler.fit_transform(X)

# %%
x.shape
# Out:
# (240, 9)

# %%
Y.shape
# Out:
# (240,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train.shape
# Out:
# (192, 9)

# %%
X_test.shape
# Out:
# (48, 9)

# %%
Y_train.shape
# Out:
# (192,)

# %%
Y_test.shape
# Out:
# (48,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score


lr_model=LogisticRegression()
lr_model.fit(X_train,Y_train)

y_lr_pred=lr_model.predict(X_test)

print('accuracy score of logistic regression: ',accuracy_score(y_lr_pred,Y_test))
print('confusion matrix of logistic regression:')
print(confusion_matrix(y_lr_pred,Y_test))
print('classification report of logistic regression: ',classification_report(y_lr_pred,Y_test))
# Out:
# accuracy score of logistic regression:  0.9375
# confusion matrix of logistic regression:
# [[24  3]
#  [ 0 21]]
# classification report of logistic regression:                precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94        27
#            1       0.88      1.00      0.93        21
#
#     accuracy                           0.94        48
#    macro avg       0.94      0.94      0.94        48
# weighted avg       0.95      0.94      0.94        48
# c:\Users\hemae\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model=DecisionTreeClassifier()
dt_model.fit(X_train,Y_train)

y_dt_pred=dt_model.predict(X_test)

print('accuracy score of Decision Tree: ',accuracy_score(y_dt_pred,Y_test))
print('confusion matrix of Decision Tree: ')
print(confusion_matrix(y_lr_pred,Y_test))
print('classification report of Decision Tree: ',classification_report(y_lr_pred,Y_test))
# Out:
# accuracy score of Decision Tree:  0.9166666666666666
# confusion matrix of Decision Tree:
# [[24  3]
#  [ 0 21]]
# classification report of Decision Tree:                precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94        27
#            1       0.88      1.00      0.93        21
#
#     accuracy                           0.94        48
#    macro avg       0.94      0.94      0.94        48
# weighted avg       0.95      0.94      0.94        48

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model=RandomForestClassifier()
rf_model.fit(X_test,Y_test)

y_rf_pred=rf_model.predict(X_test)

print('accuracy score of Random Forest: ',accuracy_score(y_rf_pred,Y_test))
print('confusion matrix of Random Forest: ')
print(confusion_matrix(y_rf_pred,Y_test))
print('classification report of Random Forest: ',classification_report(y_rf_pred,Y_test))
# Out:
# accuracy score of Random Forest:  1.0
# confusion matrix of Random Forest:
# [[24  0]
#  [ 0 24]]
# classification report of Random Forest:                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        24
#            1       1.00      1.00      1.00        24
#
#     accuracy                           1.00        48
#    macro avg       1.00      1.00      1.00        48
# weighted avg       1.00      1.00      1.00        48

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier  

param_grid={
    'n_estimators':[100,200,300],
    'max_depth':[None,10,20,30],
    'min_samples_split':[2,5],
}

model=RandomForestClassifier()

grid=GridSearchCV(model,param_grid,cv=5,scoring='accuracy')
grid.fit(X_train,Y_train)

best_rf=grid.best_estimator_
y_r_pred=best_rf.predict(X_test)

print('Best Parameters: ',grid.best_params_)
print('Accuracy: ',accuracy_score(Y_test,y_r_pred))
print(classification_report(Y_test,y_r_pred))
print(confusion_matrix(Y_test,y_r_pred))
# Out:
# Best Parameters:  {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}
# Accuracy:  0.9583333333333334
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        24
#            1       1.00      0.92      0.96        24
#
#     accuracy                           0.96        48
#    macro avg       0.96      0.96      0.96        48
# weighted avg       0.96      0.96      0.96        48
#
# [[24  0]
#  [ 2 22]]

# %%
import joblib as jb
jb.dump(rf_model,'Breastcancer.pkl')
# Out:
# ['Breastcancer.pkl']
